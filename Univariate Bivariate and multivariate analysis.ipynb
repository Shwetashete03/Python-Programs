# %%
import pandas as ad
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
print(df.describe())
# Out:
#        Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # univariate analysis

# %%
df_setosa=df.loc[df['Species']=='setosa']

# %%
df_setosa
# Out:
#     Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0            1           5.1          3.5           1.4          0.2  setosa
# 1            2           4.9          3.0           1.4          0.2  setosa
# 2            3           4.7          3.2           1.3          0.2  setosa
# 3            4           4.6          3.1           1.5          0.2  setosa
# 4            5           5.0          3.6           1.4          0.2  setosa
# 5            6           5.4          3.9           1.7          0.4  setosa
# 6            7           4.6          3.4           1.4          0.3  setosa
# 7            8           5.0          3.4           1.5          0.2  setosa
# 8            9           4.4          2.9           1.4          0.2  setosa
# 9           10           4.9          3.1           1.5          0.1  setosa
# 10          11           5.4          3.7           1.5          0.2  setosa
# ...

# %%
df_virginica
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3ecf57f31ae7> in <module>
# ----> 1 df_virginica
#
# NameError: name 'df_virginica' is not defined

# %%
df_versicolor

# %%
df_virginica=df.loc[df['Species']=='virginica']
df_versicolor=df.loc[df['Species']=='versicolor']

# %%
plt.plot(df_setosa['Sepal.Length'],np.zeros_like(df_setosa['Sepal.Length']),'o')
plt.plot(df_virginica['Sepal.Length'],np.zeros_like(df_virginica['Sepal.Length']),'o')
plt.plot(df_versicolor['Sepal.Length'],np.zeros_like(df_versicolor['Sepal.Length']),'o')
plt.xlabel('Sepal Length')
plt.show()

# %%
plt.plot(df_setosa['Sepal.Length'],np.zeros_like(df_setosa['Sepal.Length']),'o')

# %%
plt.plot(df_virginica['Sepal.Length'],np.zeros_like(df_virginica['Sepal.Length']),'o')

# %%
plt.plot(df_versicolor['Sepal.Length'],np.zeros_like(df_versicolor['Sepal.Length']),'o')

# %% [markdown]
# # Bivariate analysis

# %%
sns.FacetGrid(df,hue='Species',height=5).map(plt.scatter,'Petal.Length','Sepal.Width').add_legend();

# %% [markdown]
# # Multivariate analysis

# %%
sns.pairplot(df,hue='Species',size=3)
